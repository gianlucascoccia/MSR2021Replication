# %% [markdown]
# # Stack Overflow dataset analysis
#
# This notebook uses the MSR2021Replication scripts to run an analysis on other StackOverflow datasets, using the Mallet tool to analyze and cluster the dataset into a predetermined number of topics. This notebook aims to simplify the use of those scripts and make them more understandable and possible to be used in other datasets.

# %% [markdown]
# ## Install python libraries
#
# The notebook's first step is installing the libraries used on the scripts.

# %%
# !pip install -r notebook/requirements.txt

# %%
import nltk

nltk.download('punkt')
nltk.download('stopwords')
nltk.download('word_tokenize')

# %% [markdown]
# Import the notebook scripts to this notebook.

# %%
import sys
sys.path.insert(0, 'notebook/')

# %% [markdown]
# ## Export variables
#
# To customize the scripts to the correct dataset and output path, configure the environment variables to use the path for your dataset and configure the output folder.

# %%
# Export path to the raw dataset
# %env DATASET_PATH=./tcc/so_questions.csv

# Export the output path
# %env OUTPUT_PATH=./output

# Export the number of topics division
# %env TOPICS_NUM=15
# Out:
# env: DATASET_PATH=./tcc/so_questions.csv
# env: OUTPUT_PATH=./output
# env: TOPICS_NUM=15

# %% [markdown]
# ## Prepare dataset for Mallet
#
# The following scripts cleans the StackOverflow dataset and prepare the documents where the Mallet tool will execute the algorithm to separate the topics.

# %%
from clean_stackoverflow_data import clean_so_data
from export_so_to_mallet import export_to_mallet

print('Cleaning dataset...')
clean_so_data()

print('Exporting documents to Mallet...')
export_to_mallet()
print('Done!')
# Out:
# Folder ./output/so_data/ created!
# Cleaning dataset...
# ./tcc/so_questions.csv
# Loaded CSV!
# Removed HTML tags!
# Removed stopwords!
# Folder ./output/processed/ created!
# Saved new csv!
# Exporting documents to Mallet...
# Done!

# %% [markdown]
# ## Run the Mallet Tool
#
# The next step is to run the Mallet tool. The mallet commands are using the environment variables set in the beggining of this notebook.

# %%
# !mallet/mallet-2.0.8/bin/mallet import-dir --input $OUTPUT_PATH/so_data/ --output $OUTPUT_PATH/so.mallet --keep-sequence --remove-stopwords --extra-stopwords extra_stop_words/so.txt
# Out:
# Labels =
#    ./output/so_data/

# %%
# !mallet/mallet-2.0.8/bin/mallet train-topics --random-seed 100 --input $OUTPUT_PATH/so.mallet --num-topics 15 --optimize-interval 20 --output-state $OUTPUT_PATH/so-topic-state.gz --output-topic-keys $OUTPUT_PATH/so_keys.txt --output-doc-topics $OUTPUT_PATH/so_composition.txt --diagnostics-file $OUTPUT_PATH/so_diagnostics.xml
# Out:
# Mallet LDA: 15 topics, 4 topic bits, 1111 topic mask
# Data loaded.
# max tokens: 2249
# total tokens: 10416218
# <10> LL/token: -9,22266
# <20> LL/token: -8,65279
# <30> LL/token: -8,50522
# <40> LL/token: -8,44217
#
# 0	0,33333	native react location map code react-native latitude longitude user work create make library marker find mobile http mapview web implement
# 1	0,33333	const test animation error detox rctview true animated.view react duration type null animated import start transform code element svg function
# 2	0,33333	const import return state export dispatch store redux action date default type function case connect error reducer console.log provider react
# 3	0,33333	style view text center height width image color backgroundcolor flex touchableopacity justifycontent const fontsize alignitems onpress source row flexdirection scrollview
# 4	0,33333	react error native react-native project android file ios build expo run version path device work issue running pod code found
# 5	0,33333	item data key index flatlist const list return div false array renderitem true title modal amp classname keyextractor render row
# 6	0,33333	amp npm error react-native err module true http start react dependency expo file false node platform dev android jest version
# 7	0,33333	const user console.log error firebase function await async data return token null message false catch true usestate code useeffect amp
# 8	0,33333	screen navigation import component const home tab react navigator return stack route navigate login title header createstacknavigator navigationoptions drawer react-navigation
# 9	0,33333	component function state change react native time update work event call child code object array set button picker problem inside
# 10	0,33333	data error console.log response image fetch api const post http request url json catch file return function code header method
# 11	0,33333	android error project failed file build run task implementation compile http react-native dependency gradle release debug option find apk native
# 12	0,33333	text textinput input const password style email placeholder onchangetext button import view type react this.setstate form label amp login false
# 13	0,33333	android notification native string video react true image webview url file public camera ios permission open device link code push
# 14	0,33333	import view text component react return render class prop style extends export default button react-native onpress constructor title super this.state
#
# <50> LL/token: -8,40877
# <60> LL/token: -8,38918
# <70> LL/token: -8,37579
# <80> LL/token: -8,36675
# <90> LL/token: -8,3606
#
# 0	0,33333	native react location code map react-native library create latitude longitude work make user marker http mobile web find image api
# 1	0,33333	const test animation true detox rctview animated.view null error amp animated return duration react function false start svg transform import
# 2	0,33333	const import state return export dispatch store action redux date default type function case connect reducer provider error react mapstatetoprops
# 3	0,33333	style view text center height width color image backgroundcolor touchableopacity flex onpress const justifycontent alignitems fontsize source row scrollview flexdirection
# 4	0,33333	error react native android react-native project file ios build run expo version device path work running pod issue code xcode
# 5	0,33333	item data key index flatlist const list return array div false title renderitem true amp classname modal keyextractor object row
# 6	0,33333	npm error amp react-native err module react http start true dependency expo file node android install jest platform version dev
# 7	0,33333	const user console.log error firebase await function async data token return message null catch login false code true useeffect usestate
# 8	0,33333	screen import navigation component const home tab react navigator return title stack route navigate header login createstacknavigator navigationoptions icon drawer
# 9	0,33333	component function state react native change time button work update call code event user problem set child inside screen picker
# 10	0,33333	image data error response console.log fetch const api url http file request post json catch return code function header server
# 11	0,33333	android error project failed file run build task implementation compile http dependency react-native gradle release native debug option find exception
# 12	0,33333	text textinput input const style password email placeholder onchangetext type button label view this.setstate form amp react false true field
# 13	0,33333	android notification string video native true import webview public react url camera void permission push activity code return ios open
# 14	0,33333	import view text component react return render class prop extends style export default button react-native constructor onpress super this.setstate this.state
#
# <100> LL/token: -8,35576
# <110> LL/token: -8,35281
# <120> LL/token: -8,35084
# <130> LL/token: -8,34728
# <140> LL/token: -8,34461
#
# 0	0,33333	native react location code map library react-native latitude create longitude mobile marker user work web make http api find ios
# 1	0,33333	const test animation true detox rctview amp animated.view null false animated duration return function start view transform width svg height
# 2	0,33333	const import state return export dispatch store redux action date default type case function connect reducer provider react error console.log
# 3	0,33333	style view text center width height color image touchableopacity backgroundcolor flex onpress const justifycontent alignitems fontsize source scrollview row flexdirection
# 4	0,33333	error react native android react-native project ios build file run version expo device path work pod running issue xcode command
# 5	0,33333	item data key index flatlist const array list return div false title renderitem true amp object classname keyextractor console.log row
# 6	0,33333	npm error amp react-native err module react start http true dependency expo file node version jest install android platform project
# 7	0,33333	const user console.log error firebase await function async data token return message null catch login false code true amp useeffect
# 8	0,33333	screen import navigation component const home tab react navigator return title navigate stack route header login icon createstacknavigator navigationoptions export
# 9	0,33333	component react native function state change time button work code update user call screen problem event set make inside child
# 10	0,33333	image error data response console.log fetch const api url http file request post json catch code return header function native
# 11	0,33333	android error project failed file run build task implementation compile http react-native dependency gradle native release debug find option exception
# 12	0,33333	text textinput input const style password placeholder email onchangetext label type view this.setstate button form amp false react field true
# 13	0,33333	android notification import string video true webview native public url return void camera react permission push activity ios override code
# 14	0,33333	import view text component react return render class prop extends style export default react-native button constructor super this.setstate onpress this.state
#
# <150> LL/token: -8,34266
# <160> LL/token: -8,34034
# <170> LL/token: -8,33872
# <180> LL/token: -8,33746
# <190> LL/token: -8,33704
#
# 0	0,33333	native react location map code react-native library latitude longitude create mobile marker web work http api ios user find make
# 1	0,33333	const test animation true false amp detox rctview animated.view width return height null animated duration function view start react position
# 2	0,33333	const import state return export dispatch store redux action date default type function case connect reducer provider error mapstatetoprops console.log
# 3	0,33333	style view text center width height color image touchableopacity backgroundcolor flex onpress const justifycontent alignitems fontsize source import row scrollview
# 4	0,33333	error android react native react-native project build ios run file version device expo path pod running work issue command xcode
# 5	0,33333	item data key index flatlist array const list return div title renderitem false amp object true classname keyextractor console.log row
# 6	0,33333	npm error amp react-native err module react start http true dependency expo file node jest version android project install native
# 7	0,33333	const user console.log error firebase function await async data token return message null catch login false code true amp useeffect
# 8	0,33333	screen import navigation component const home tab react navigator return title stack navigate route header login icon createstacknavigator navigationoptions drawer
# 9	0,33333	react native component change function state time button work code screen user update problem call event make set inside question
# 10	0,33333	image error data response console.log fetch const url api file http request post json catch code return header function native
# 11	0,33333	android error project failed file run build task implementation compile http react-native dependency gradle native release debug option find exception
# 12	0,33333	text textinput input const style password placeholder email onchangetext label view type this.setstate button form amp react false true field
# 13	0,33333	android notification import string video true webview public native return void url push react permission camera activity override ios code
# 14	0,33333	import view component text react return render class prop extends export style default react-native button constructor super this.setstate this.state onpress
# <200> LL/token: -8,33591
# <210> LL/token: -8,33503
# [beta: 0,01705]
# <220> LL/token: -8,31239
# <230> LL/token: -8,28166
# [beta: 0,01756]
# <240> LL/token: -8,27068
#
# 0	0,2362	native react location map code react-native library latitude longitude mobile web marker http api create user ios google link android
# 1	0,07465	const test animation true false detox rctview animated.view height width amp animated null return duration svg transform view start position
# 2	0,11241	const import state return dispatch export store redux action date default type case function connect reducer provider mapstatetoprops error console.log
# 3	0,21803	style view text center width height color image touchableopacity backgroundcolor flex onpress const justifycontent alignitems fontsize source import react row
# 4	0,26633	error android react native react-native project file build ios run version expo device path running pod work issue command code
# 5	0,16718	item data key flatlist index const array return list div renderitem title false object amp classname true console.log keyextractor row
# 6	0,11381	npm error amp react-native err module react true start dependency http expo file jest install node android version platform dev
# 7	0,1681	const user console.log error firebase function await data async token return message null catch login false code true email amp
# 8	0,15429	screen import navigation component const home tab react navigator return title route login stack header navigate createstacknavigator icon navigationoptions drawer
# 9	0,37761	react native component change work screen code time function button state user problem make update call set event page issue
# 10	0,17184	image error data response console.log const fetch url file api http request post catch return json header code function await
# 11	0,06047	android project failed error file run task build implementation compile http gradle dependency react-native release debug native option find true
# 12	0,1154	text textinput input style const password placeholder label email onchangetext view this.setstate type amp form button false true field picker
# 13	0,11496	android notification import string video public true webview return void native url override permission push activity camera null false ios
# 14	0,24662	import view component text react return render class prop extends export style default react-native button constructor this.setstate super this.state onpress
#
# <250> LL/token: -8,24736
# [beta: 0,01771]
# <260> LL/token: -8,24251
# <270> LL/token: -8,22502
# [beta: 0,01782]
# <280> LL/token: -8,22185
# <290> LL/token: -8,20965
#
# 0	0,13252	react native location map latitude longitude marker amp web mapview google mobile api code link react-native http facebook coordinate data
# 1	0,03647	const test true animation false detox rctview animated.view height width amp return animated null duration view svg transform start view.js
# 2	0,06172	const import state return dispatch export store action redux date default type function case connect reducer mapstatetoprops provider console.log error
# 3	0,15456	style view text center width height color image backgroundcolor touchableopacity flex onpress const justifycontent alignitems fontsize import source react button
# 4	0,20538	error android react native react-native project file ios build run expo device version path running pod work command code issue
# 5	0,10711	item data flatlist index key const array return list div renderitem title false amp object classname true console.log keyextractor usestate
# 6	0,05743	npm error amp err react-native module react true dependency start http expo file jest android false install node version dev
# 7	0,10556	const user console.log error firebase function await data async return token message null login catch false code email true useeffect
# 8	0,09432	screen import navigation component const home tab navigator react return title stack route login header createstacknavigator navigate navigationoptions drawer export
# 9	0,35428	react native component work code screen change time user function button problem state make set call update question react-native issue
# 10	0,10809	image error data response console.log const fetch url file http api request return post catch code await json function header
# 11	0,02386	android project error failed file build run task implementation compile http dependency gradle react-native release debug native option find true
# 12	0,06561	text textinput input style const placeholder label password onchangetext email view this.setstate type amp form button false true picker field
# 13	0,0623	android notification import string video public true webview return void native override permission push url camera activity false null class
# 14	0,17932	import view component text react return render class prop extends export style default react-native button constructor this.setstate error function super
#
# [beta: 0,01794]
# <300> LL/token: -8,20675
# <310> LL/token: -8,19775
# [beta: 0,01803]
# <320> LL/token: -8,19448
# <330> LL/token: -8,18695
# [beta: 0,0181]
# <340> LL/token: -8,18372
#
# 0	0,03934	location map latitude longitude const marker amp mapview coordinate region true position error null lat key facebook object address code
# 1	0,02549	const test true false animation detox rctview height animated.view width amp return view animated duration null svg transform start function
# 2	0,04264	const import state return dispatch export store action redux date default type function case connect reducer mapstatetoprops provider error console.log
# 3	0,11786	style view text center width height color image backgroundcolor touchableopacity flex onpress const justifycontent import alignitems fontsize source react button
# 4	0,15583	error android react native react-native project ios file build run expo version device path pod running command work code xcode
# 5	0,07941	item data flatlist index key const array return list div renderitem title false amp object true classname console.log state keyextractor
# 6	0,03668	npm error amp err react-native module true react start dependency http expo file jest install android false test version platform
# 7	0,07706	const user console.log error firebase function await data async token return message login catch null code email false true amp
# 8	0,06877	screen import navigation component const home tab navigator react return title stack route login header createstacknavigator export navigate navigationoptions drawer
# 9	0,32797	react native work code component user screen change time make problem react-native button working function show question set call issue
# 10	0,07613	image error data console.log response const fetch url file http api request return catch post await json function code header
# 11	0,0158	android project error failed file run build task implementation compile http dependency gradle react-native release debug native option find true
# 12	0,04686	text textinput input style const placeholder label password onchangetext email view this.setstate type amp button form false return field picker
# 13	0,04377	android notification import string webview video public true return void override native url permission push camera false null activity ios
# 14	0,13459	import view component text react return class render prop extends style export default button react-native constructor function error super this.setstate
#
# <350> LL/token: -8,17786
# [beta: 0,01813]
# <360> LL/token: -8,17595
# <370> LL/token: -8,17314
# [beta: 0,01815]
# <380> LL/token: -8,17229
# <390> LL/token: -8,16963
#
# 0	0,02333	location map latitude longitude const marker amp mapview coordinate region true error null lat position object key facebook address react-native-maps
# 1	0,02328	const test true false animation detox rctview animated.view height width amp return view null animated duration function svg transform position
# 2	0,03884	const import state return export dispatch store action redux date default type function case reducer connect mapstatetoprops provider console.log error
# 3	0,10821	style view text center height width color image backgroundcolor touchableopacity flex onpress const import justifycontent alignitems fontsize source react button
# 4	0,12942	error android react react-native native project file build run version expo ios device path pod running command xcode found install
# 5	0,07243	item data flatlist index const key array return list div renderitem title false object amp true classname console.log state function
# 6	0,0327	npm error amp err react-native module react true start dependency http expo file jest false android install version node platform
# 7	0,06913	const user console.log error firebase function data await async token return message login catch null false email code true amp
# 8	0,06262	screen import navigation component const home tab navigator react return title stack route login header createstacknavigator export navigationoptions drawer navigate
# 9	0,31611	react native work code user component screen react-native time change problem make working android button issue question show create set
# 10	0,06758	error image console.log data response const fetch file url http api request return catch post await function json code header
# 11	0,01456	android project error failed file run build task implementation compile http dependency gradle react-native release debug native option find true
# 12	0,04299	text textinput input style const label placeholder password onchangetext view email this.setstate type button amp form false picker true import
# 13	0,03896	android notification import string true public video return webview void override url permission push native false camera null activity key
# 14	0,12333	import component view text react return prop render class extends style export default button react-native function constructor this.setstate error super
# [beta: 0,01819]
# <400> LL/token: -8,16964
# <410> LL/token: -8,16806
# [beta: 0,01822]
# <420> LL/token: -8,16804
# <430> LL/token: -8,16651
# [beta: 0,01823]
# <440> LL/token: -8,16666
#
# 0	0,01865	location const map latitude longitude marker amp mapview coordinate true error region null lat position object key console.log return code
# 1	0,02225	const true test animation false rctview detox animated.view width height amp view return null animated duration svg function start transform
# 2	0,0365	const import state return dispatch export store redux action date default type function case reducer connect mapstatetoprops provider console.log error
# 3	0,10123	style view text center width height color image backgroundcolor touchableopacity flex onpress import const justifycontent alignitems fontsize source react button
# 4	0,10068	error android react-native react project native build file run version expo ios device path pod command running xcode failed install
# 5	0,0679	item data flatlist index const key array return list div renderitem title false object amp classname true console.log state function
# 6	0,03038	npm error amp err react-native module react true start dependency http expo file jest android install false version platform test
# 7	0,0617	const user console.log error firebase function await data async token return message login catch null email false code true amp
# 8	0,05831	screen import navigation component const home tab react navigator return title stack login route createstacknavigator header export navigate drawer navigationoptions
# 9	0,30139	react native work code user react-native screen component time android change problem make working issue ios http show question create
# 10	0,06135	error image data console.log response const fetch url file http api request catch return post function await json code header
# 11	0,0135	android project error failed file run build task implementation compile dependency http gradle react-native release debug native option find true
# 12	0,04024	text textinput input style const label placeholder password onchangetext view email this.setstate button amp type form false import return picker
# 13	0,03368	android notification import string true public video return void webview override url permission false push native activity key null class
# 14	0,11494	component view import text react return prop render class extends style export default button react-native function constructor error this.setstate super
#
# <450> LL/token: -8,16537
# [beta: 0,01825]
# <460> LL/token: -8,16536
# <470> LL/token: -8,16481
# [beta: 0,01826]
# <480> LL/token: -8,16481
# <490> LL/token: -8,16423
#
# 0	0,01758	location const latitude map longitude marker mapview amp coordinate error region true null lat position console.log object key code return
# 1	0,02196	const true test animation false height detox rctview width animated.view amp return view animated null duration function svg start position
# 2	0,03558	const import state return dispatch export redux store action date default type function case reducer connect mapstatetoprops error console.log provider
# 3	0,09804	style view text center width height color image backgroundcolor touchableopacity flex onpress import const justifycontent alignitems fontsize source react button
# 4	0,08882	error android react-native project react native build run file version expo ios path pod device command running xcode failed install
# 5	0,06618	item data flatlist index key const array return list div renderitem title object false amp true state classname console.log function
# 6	0,02954	npm error amp err react-native module react true start dependency http expo file jest android install version false test dev
# 7	0,05896	const user console.log error firebase function await data async token return message login catch null email false code true amp
# 8	0,05692	screen import navigation component const home tab react navigator return title stack route header login export createstacknavigator navigate navigationoptions drawer
# 9	0,29551	react native work code user react-native android screen change time problem component make working ios issue http image question create
# 10	0,05802	error image console.log data response const fetch url file http api request return catch post function await header json code
# 11	0,01317	android project error failed file run build task implementation compile http dependency gradle react-native release debug native option find true
# 12	0,03885	text textinput style input const label placeholder password onchangetext view email this.setstate button type amp form import false return picker
# 13	0,03188	android notification import string true public video return void override permission webview push false null url key activity class camera
# 14	0,11144	component view import text react return render prop class extends style export default button react-native function constructor error this.setstate super
#
# [beta: 0,01828]
# <500> LL/token: -8,16374
# <510> LL/token: -8,16313
# [beta: 0,01829]
# <520> LL/token: -8,16351
# <530> LL/token: -8,16234
# [beta: 0,0183]
# <540> LL/token: -8,16267
#
# 0	0,01698	location const map latitude longitude marker mapview amp error coordinate true region null lat position object console.log return code key
# 1	0,02146	const true animation test false height rctview detox animated.view width amp view return animated duration null function start svg position
# 2	0,035	const import state return dispatch export store redux action date default type function case reducer connect mapstatetoprops error console.log provider
# 3	0,09582	style view text center width height color image backgroundcolor touchableopacity flex import onpress const justifycontent alignitems fontsize react source button
# 4	0,07916	error android react-native project react build run native file version path ios pod expo command device running xcode failed install
# 5	0,0641	item data flatlist index const key array return list div renderitem title false object amp true state console.log classname function
# 6	0,02863	npm error amp err react-native module true react dependency start http expo file jest android false version install test platform
# 7	0,05602	const user console.log error firebase function await data async return token message login catch null email code false true amp
# 8	0,05537	screen import navigation component const home tab react navigator return title stack route header login export createstacknavigator navigationoptions navigate drawer
# 9	0,28826	native react work code react-native user android screen change problem time make working component ios issue http image show expo
# 10	0,05543	error image console.log response data const fetch url file http api request return catch await post function code header json
# 11	0,01273	android project error failed file build run implementation task compile dependency http gradle react-native release debug native find option true
# 12	0,03792	text textinput style input const label placeholder password onchangetext view email this.setstate button amp type form import false return true
# 13	0,03039	android notification import string true public return video void override webview permission false key push null url activity class camera
# 14	0,1072	component view import text react return render prop class extends export style default button function react-native constructor error this.setstate super
#
# <550> LL/token: -8,16222
# [beta: 0,01831]
# <560> LL/token: -8,16225
# <570> LL/token: -8,16202
# [beta: 0,01831]
# <580> LL/token: -8,16216
# <590> LL/token: -8,16108
#
# 0	0,01659	location const latitude longitude map marker amp mapview error coordinate region true null lat position console.log object key return code
# 1	0,0214	const true animation test false height width rctview detox animated.view amp view return function animated null duration position svg start
# 2	0,03471	const import state return export dispatch action redux store date default type function case reducer connect mapstatetoprops error console.log provider
# 3	0,09499	style view text center width height color image touchableopacity backgroundcolor flex import onpress const justifycontent alignitems fontsize react source button
# 4	0,07516	error android react-native project build react run native file version path pod ios command expo running device xcode failed install
# 5	0,06308	item data flatlist index const key array return list div renderitem title object false amp true state text console.log function
# 6	0,02841	npm error amp err react-native module react true start dependency http expo file jest android version test install false platform
# 7	0,05494	const user console.log error firebase function await data async return token message login catch null email code false true amp
# 8	0,05514	screen import navigation component const home tab react navigator return title stack export route login header createstacknavigator default drawer navigate
# 9	0,28416	react native work code react-native android user screen problem change time make working ios component issue http image expo create
# 10	0,05464	error image console.log response data const fetch url file http api request return catch post function await header json code
# 11	0,01255	android project error failed file run build task implementation compile dependency http gradle react-native release debug native find option true
# 12	0,03765	text textinput input style const label placeholder password onchangetext view email this.setstate button type form amp import false return true
# 13	0,02962	android notification import string true public return video void override key webview permission false push null url activity class camera
# 14	0,10585	component view import text react return render prop class extends export style button default function react-native constructor error this.setstate super
# [beta: 0,01832]
# <600> LL/token: -8,16129
# <610> LL/token: -8,16187
# [beta: 0,01832]
# <620> LL/token: -8,16125
# <630> LL/token: -8,16072
# [beta: 0,01834]
# <640> LL/token: -8,16089
#
# 0	0,01653	location const latitude map longitude marker amp mapview error coordinate true region null lat position console.log object return key code
# 1	0,02132	const true animation test false height width rctview detox animated.view amp return view animated function duration null start svg position
# 2	0,03436	const import state return export dispatch action store redux date default function type case reducer connect error mapstatetoprops console.log provider
# 3	0,0934	style view text center width height color image touchableopacity backgroundcolor flex import onpress const justifycontent alignitems fontsize react source button
# 4	0,07089	error android react-native project build react run native file version path pod ios command running expo device failed xcode install
# 5	0,06228	item data flatlist index key const array return list renderitem div title object false amp true state text console.log function
# 6	0,0284	npm error amp err react-native module react true start dependency http expo file jest android install version test false platform
# 7	0,05394	const user console.log error firebase function await data async token return message login catch null email code false true amp
# 8	0,05437	screen import navigation component const home tab react navigator return title export stack login route header createstacknavigator drawer navigationoptions navigate
# 9	0,27973	react native work code react-native android user screen problem time change working make ios component issue http image expo show
# 10	0,05377	error image console.log response data const fetch url file http api request return catch post await function header json code
# 11	0,01226	android project error failed file build implementation task run compile dependency http gradle react-native release debug native find option true
# 12	0,03716	text textinput input style const label placeholder onchangetext password view email this.setstate button amp type form import false return true
# 13	0,02911	android notification import string true public return video void override permission webview false key push null class activity url camera
# 14	0,10379	component view import text react return prop render class extends style export button default function react-native constructor error this.setstate super
#
# <650> LL/token: -8,16054
# [beta: 0,01833]
# <660> LL/token: -8,16131
# <670> LL/token: -8,16028
# [beta: 0,01834]
# <680> LL/token: -8,16086
# <690> LL/token: -8,16033
#
# 0	0,01623	location const latitude longitude map marker amp mapview error coordinate true region null lat position console.log object key return data
# 1	0,02115	const true animation test false height width rctview detox animated.view amp return view animated duration function null position start svg
# 2	0,03427	const import state return dispatch export action store redux date default type function case reducer connect console.log mapstatetoprops error provider
# 3	0,09281	style view text center height width color image touchableopacity backgroundcolor flex import onpress const justifycontent alignitems react fontsize source button
# 4	0,06967	error android project react-native build run react native file version pod path ios command running device failed xcode expo install
# 5	0,06228	item data flatlist index const key array return list renderitem title object div false amp true state text console.log function
# 6	0,02828	npm error amp err react-native module react true start dependency http expo file jest android install test version false platform
# 7	0,05359	const user console.log error firebase function await data async token return message login catch null email false code true amp
# 8	0,05395	screen import navigation component const home tab react navigator return title stack export route login header createstacknavigator navigate navigationoptions drawer
# 9	0,27806	react native work code react-native android user screen problem time change make working ios component issue http expo image show
# 10	0,05332	error image console.log response data const fetch url file http api request return catch post function await header json code
# 11	0,01224	android project error failed file build implementation run task compile dependency http gradle react-native release debug native find option true
# 12	0,03665	text textinput input style const label placeholder password onchangetext view email this.setstate button type amp form import false return true
# 13	0,02895	android notification import string true public return video void override permission false webview key null push activity class url camera
# 14	0,10308	component view import text react return prop render class extends export style button default function react-native constructor this.setstate error super
#
# [beta: 0,01834]
# <700> LL/token: -8,16028
# <710> LL/token: -8,16023
# [beta: 0,01834]
# <720> LL/token: -8,16065
# <730> LL/token: -8,16063
# [beta: 0,01834]
# <740> LL/token: -8,15995
#
# 0	0,01622	location const latitude longitude map marker amp mapview error coordinate true region null lat position console.log object key return code
# 1	0,02098	const true animation test false height width rctview detox animated.view amp view return animated duration null function position start transform
# 2	0,03453	const import state return export dispatch redux action store date default function type case reducer connect error mapstatetoprops console.log provider
# 3	0,09238	style view text center width height color image touchableopacity backgroundcolor flex import onpress const justifycontent alignitems react fontsize source button
# 4	0,06767	error android react-native project build run react file native version pod path command ios running failed device xcode expo install
# 5	0,062	item data flatlist index const key array return list renderitem title object false div amp true text state console.log function
# 6	0,02835	npm error amp err react-native module react true dependency start http expo file jest android version test install false platform
# 7	0,05321	const user console.log error firebase function data await async token return message login catch null email code false true amp
# 8	0,05407	screen import navigation component const home tab react navigator return title stack export route login header createstacknavigator navigationoptions default drawer
# 9	0,27561	react native work code react-native android user screen problem change time ios working make issue component http expo image show
# 10	0,05287	error image console.log response data const fetch url file http api request return catch post function await header code json
# 11	0,01198	android project error failed file implementation task build run compile dependency http gradle react-native release debug native find option true
# 12	0,03669	text textinput input style const label placeholder password onchangetext email view this.setstate button type amp form import false return true
# 13	0,02848	android notification import string true public return video void override permission false key push null webview activity class url native
# 14	0,10251	component view import text react return prop render class extends export style button default function react-native constructor error this.setstate super
#
# <750> LL/token: -8,16033
# [beta: 0,01834]
# <760> LL/token: -8,15993
# <770> LL/token: -8,16004
# [beta: 0,01835]
# <780> LL/token: -8,1598
# <790> LL/token: -8,15985
#
# 0	0,01613	location const latitude longitude map marker amp mapview error coordinate true region null lat position object console.log return code key
# 1	0,02101	const true animation false test width height detox rctview animated.view amp view return animated duration function null start position svg
# 2	0,03431	const import state return dispatch export redux action store date default type function case reducer connect mapstatetoprops error console.log provider
# 3	0,09241	style view text center height width color image touchableopacity backgroundcolor flex import onpress const justifycontent alignitems react fontsize source button
# 4	0,06641	error android project react-native build run react file native version path pod command ios running failed xcode device install expo
# 5	0,06196	item data flatlist index key const array return list renderitem title object false div amp state text true console.log function
# 6	0,02854	npm error amp err react-native react module true start dependency http expo file jest android test version install false platform
# 7	0,05273	const user console.log error firebase function await data async return token message login catch null email code false true amp
# 8	0,05385	screen import navigation component const home tab react navigator return title stack export route header login createstacknavigator navigationoptions drawer default
# 9	0,27466	native react work code react-native android user screen problem time working ios change make issue expo component http image show
# 10	0,05274	error image console.log response data const fetch url file http api request return catch post await function header code json
# 11	0,01197	android project error failed file implementation build task run compile dependency http gradle react-native release debug native find true def
# 12	0,03664	text textinput input style const label placeholder onchangetext password email view this.setstate button type amp form import false return picker
# 13	0,02835	android notification import string true public return video void override false permission key null push webview activity class url native
# 14	0,10193	component view import text react return prop render class extends export button style default function react-native constructor this.setstate super onpress
# [beta: 0,01835]
# <800> LL/token: -8,15969
# <810> LL/token: -8,15987
# [beta: 0,01835]
# <820> LL/token: -8,15924
# <830> LL/token: -8,15961
# [beta: 0,01835]
# <840> LL/token: -8,15955
#
# 0	0,01607	location const latitude longitude map marker mapview amp error coordinate true region null position lat console.log object return key code
# 1	0,02086	const true animation test false width height rctview detox animated.view amp view return animated function duration null svg start position
# 2	0,03426	const import state return export dispatch redux store action date default function type case reducer connect mapstatetoprops console.log provider error
# 3	0,09224	style view text center height width color image touchableopacity backgroundcolor flex import onpress const justifycontent react alignitems fontsize source button
# 4	0,06487	error android project react-native build run react file native version path pod command ios failed running xcode device install debug
# 5	0,06175	item data flatlist index key const array return list renderitem title object false amp div text state true console.log function
# 6	0,02869	npm error amp err react-native react module true dependency start http expo file jest android version install test false platform
# 7	0,05268	const user console.log error firebase function await data async return token message login catch null email code false true amp
# 8	0,05377	screen import navigation component const home tab react navigator return title stack export header route login createstacknavigator navigationoptions navigate drawer
# 9	0,27355	react native work code react-native android user screen problem ios working time change make issue expo http component image device
# 10	0,05228	error image console.log response data const fetch url file http api request return catch post await function header code json
# 11	0,01181	android project error file failed implementation task build run compile dependency gradle http react-native release native debug true find def
# 12	0,03644	text textinput input style const label placeholder onchangetext password view email this.setstate button type amp form import false true return
# 13	0,02805	android notification import string true public return video void override permission key false null webview push activity class url native
# 14	0,10143	component view import text react return prop render class extends export button style default function react-native constructor error this.setstate super
#
# <850> LL/token: -8,15926
# [beta: 0,01836]
# <860> LL/token: -8,1594
# <870> LL/token: -8,15929
# [beta: 0,01836]
# <880> LL/token: -8,15981
# <890> LL/token: -8,15949
#
# 0	0,01585	location const latitude longitude map marker mapview amp error coordinate true region null lat position console.log object return key code
# 1	0,02091	const true animation false test height width rctview detox animated.view view amp return animated duration function null position svg start
# 2	0,03416	const import state return export dispatch redux store action date default type function case reducer connect mapstatetoprops error console.log provider
# 3	0,09199	style view text center height width color image touchableopacity backgroundcolor flex import onpress const justifycontent react alignitems fontsize source button
# 4	0,06399	error android project react-native build run react file native version pod path command failed ios running xcode device install debug
# 5	0,06173	item data flatlist index key const array return list renderitem title object false amp div text true state console.log keyextractor
# 6	0,02877	npm error amp err react-native module react true dependency start expo http file jest android version test install project platform
# 7	0,05271	const user console.log error firebase function await data async token return message login catch null email code false true amp
# 8	0,05385	screen import navigation component const home tab react navigator return title stack export route login header createstacknavigator navigate navigationoptions drawer
# 9	0,27328	react native work code react-native android user screen problem ios time change working make expo issue http component image device
# 10	0,05234	error image console.log response data const fetch url file http api request return catch post await function header json code
# 11	0,01181	android project error file failed implementation task build run compile dependency gradle http release react-native native debug true find def
# 12	0,03657	text textinput input style const label placeholder onchangetext password view email this.setstate button type amp form false import return true
# 13	0,0281	android notification import string true public return video void override permission false key null webview push activity url class camera
# 14	0,10204	component view import text react return prop render class extends export button style function default react-native constructor error this.setstate super
#
# [beta: 0,01835]
# <900> LL/token: -8,15925
# <910> LL/token: -8,15915
# [beta: 0,01836]
# <920> LL/token: -8,15944
# <930> LL/token: -8,15956
# [beta: 0,01837]
# <940> LL/token: -8,15952
#
# 0	0,01588	location const latitude longitude map marker mapview amp error coordinate true region null lat position console.log object key return code
# 1	0,02109	const true animation false height width test detox rctview animated.view amp view return animated duration position null function svg start
# 2	0,03409	const import state return dispatch export redux store action date default type function case reducer connect mapstatetoprops error console.log provider
# 3	0,09171	style view text center width height color image touchableopacity backgroundcolor flex import onpress const justifycontent react alignitems fontsize source button
# 4	0,06304	error android build project react-native run react file native version pod path failed command running ios xcode install device debug
# 5	0,06175	item data flatlist index key const array return list renderitem title object false amp div text true state console.log keyextractor
# 6	0,02922	npm error amp err react-native react module true start dependency expo http file jest android version test install false project
# 7	0,05283	const user console.log error firebase function data await async token return message login catch null email code false true amp
# 8	0,05355	screen import navigation component const home tab react navigator return title stack export route login header createstacknavigator navigate navigationoptions default
# 9	0,27395	native react work code react-native android user screen ios problem working change time make expo issue http image component device
# 10	0,05254	error image console.log response const data fetch url file http api request return catch post await function header json code
# 11	0,01145	android project error file implementation failed task build run compile dependency gradle http release react-native native debug true find def
# 12	0,03633	text textinput input style const label placeholder onchangetext password email view this.setstate button type amp form import false return picker
# 13	0,02789	android notification import string true public return video void override permission key false null push webview activity class url camera
# 14	0,10156	component view import text react return prop render class extends export button style default function react-native constructor this.setstate error super
#
# <950> LL/token: -8,1596
# [beta: 0,01836]
# <960> LL/token: -8,15944
# <970> LL/token: -8,15936
# [beta: 0,01836]
# <980> LL/token: -8,15992
# <990> LL/token: -8,15972
#
# 0	0,01592	location const latitude longitude map marker mapview amp error coordinate true region null position lat console.log object key return code
# 1	0,02112	const true animation false height width test rctview detox animated.view view amp return animated duration position null start function svg
# 2	0,03399	const import state return export dispatch redux store action date default type function case reducer connect mapstatetoprops console.log error provider
# 3	0,09174	style view text center width height color image touchableopacity backgroundcolor flex import onpress const justifycontent react alignitems fontsize source button
# 4	0,06187	error build android run project react-native react file native version failed pod path command running ios xcode install device debug
# 5	0,06156	item data flatlist index key const array return list renderitem title object false amp text div state true console.log view
# 6	0,0293	npm error amp err react-native module react true start dependency expo http file jest android version test install platform false
# 7	0,05264	const user console.log error firebase function await data return async token message login catch null email code false true amp
# 8	0,05367	screen import navigation component const home tab react navigator return title export stack header route login createstacknavigator navigate navigationoptions default
# 9	0,27455	native react work code react-native android user screen ios problem working time change make expo issue http component image device
# 10	0,05232	error image console.log response data const fetch url file http api request return catch await post function header json code
# 11	0,01131	android project file error implementation task failed build run compile dependency gradle http release react-native native true find def debug
# 12	0,03646	text textinput input style const label placeholder onchangetext password view email this.setstate button type amp form false import true return
# 13	0,0279	android notification import string true public return video void override key permission false null push webview class activity native camera
# 14	0,1018	component view import text react return prop render class extends export button style default function react-native constructor error this.setstate super
# [beta: 0,01837]
# <1000> LL/token: -8,15953
#
# Total time: 12 minutes 32 seconds

# %% [markdown]
# ## Parse results
#
# The following script parse the mallet output and place all questions from the same topic into one file. Resulting in one file per document.

# %%
from parse_topics_composition import parse_topics
from unite_topics_in_one_file import unite_questions_documents_by_topic

print('Parsing topics...')
parse_topics()
print('Uniting questions by topic...')
unite_questions_documents_by_topic()
print('Done!')
# Out:
# Parsing topics...
# Uniting questions by topic...
# Folder ./output/topics created!
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-29a7dd9bcc7f> in <module>
#       5 parse_topics()
#       6 print('Uniting questions by topic...')
# ----> 7 unite_questions_documents_by_topic()
#       8 print('Done!')
#
# ~/Documents/UnB/TCC/MSR2021Replication/notebook/unite_topics_in_one_file.py in unite_questions_documents_by_topic()
#      28     file = get_output_file(
#      29         'topics/{}.csv'.format(topic))
# ---> 30     so = pd.read_csv(file)
#      31     for _, row in so.iterrows():
#      32       df_to_file(row,  topic)
#
# /opt/homebrew/lib/python3.9/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     608     kwds.update(kwds_defaults)
#     609
# --> 610     return _read(filepath_or_buffer, kwds)
#     611
#     612
#
# /opt/homebrew/lib/python3.9/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     460
#     461     # Create the parser.
# --> 462     parser = TextFileReader(filepath_or_buffer, **kwds)
#     463
#     464     if chunksize or iterator:
#
# /opt/homebrew/lib/python3.9/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     817             self.options["has_index_names"] = kwds["has_index_names"]
#     818
# --> 819         self._engine = self._make_engine(self.engine)
#     820
#     821     def close(self):
#
# /opt/homebrew/lib/python3.9/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1048             )
#    1049         # error: Too many arguments for "ParserBase"
# -> 1050         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1051
#    1052     def _failover_to_python(self):
#
# /opt/homebrew/lib/python3.9/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1865
#    1866         # open handles
# -> 1867         self._open_handles(src, kwds)
#    1868         assert self.handles is not None
#    1869         for key in ("storage_options", "encoding", "memory_map", "compression"):
#
# /opt/homebrew/lib/python3.9/site-packages/pandas/io/parsers.py in _open_handles(self, src, kwds)
#    1360         Let the readers open IOHanldes after they are done with their potential raises.
#    1361         """
# -> 1362         self.handles = get_handle(
#    1363             src,
#    1364             "r",
#
# /opt/homebrew/lib/python3.9/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     640                 errors = "replace"
#     641             # Encoding
# --> 642             handle = open(
#     643                 handle,
#     644                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: './output/topics/topic_1.csv'
